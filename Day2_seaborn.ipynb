# %%
#All codes are available at https://github.com/MyDataCafe/
#All Class Videos are at https://www.youtube.com/mydatacafe
#We are on Facebook https://www.facebook.com/mydatacafe/
#We are on LinkedIn https://www.linkedin.com/company/mydatacafe/

# %%
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')#inbuilt package in seaborn
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# # distplot

# %%
#distribution of a univariate set of observations
sns.distplot(tips['total_bill'])#to omit the blue curve use kde=False
#use bins=50,40,etc kernel density estimator

# %% [markdown]
# # jointplot

# %%
#jointplot() allows you 
#match up two distplots for bivariate data
#kind="scatter" | "reg" | "resid" | "kde" | "hex" options

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind="scatter")

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind="reg")

# %% [markdown]
# # pairplot

# %%
#pairplot will plot pairwise relationships across an entire dataframe
#(for the numerical columns) and supports a color hue 
#argument (for categorical columns).

# %%
sns.pairplot(tips,hue="sex")

# %%
sns.pairplot(tips[["total_bill","sex"]],hue="sex")
#if you want histogram with color from a category

# %%
sns.pairplot(tips.iloc[:,[0,3]],hue="smoker") #this time using index 
#to select columns

# %%
tips.corr() #to find co-relation in a datafrmae
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
tips.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
#to get it as a plot
# Out:
#         <style  type="text/css" >
#
#
#             #T_e031a71e_a349_11e7_8954_3417eb6923afrow0_col0 {
#
#                 background-color:  #b40426;
#
#             }
#
#             #T_e031a71e_a349_11e7_8954_3417eb6923afrow0_col1 {
#
#                 background-color:  #799cf8;
#
#             }
#
#             #T_e031a71e_a349_11e7_8954_3417eb6923afrow0_col2 {
#
#                 background-color:  #3b4cc0;
#
#             }
#
#             #T_e031a71e_a349_11e7_8954_3417eb6923afrow1_col0 {
#
#                 background-color:  #b5cdfa;
#
#             }
#
#             #T_e031a71e_a349_11e7_8954_3417eb6923afrow1_col1 {
#
#                 background-color:  #b40426;
#
#             }
#
#             #T_e031a71e_a349_11e7_8954_3417eb6923afrow1_col2 {
#
#                 background-color:  #3b4cc0;
#
#             }
#
#             #T_e031a71e_a349_11e7_8954_3417eb6923afrow2_col0 {
#
#                 background-color:  #80a3fa;
#
#             }
#
# ...

# %%
sns.heatmap(tips.corr(),cmap='coolwarm',annot=True)

# %% [markdown]
# # barplot and countplot

# %%
#These very similar plots allow you to get aggregate data off a categorical 
#feature in your data. barplot is a general plot that allows you to 
#aggregate the categorical data based off some function, by default the mean
sns.barplot(x='sex',y='total_bill',data=tips)

# %%
import numpy as np
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)

# %% [markdown]
# # countplot

# %%
#same as barplot except the estimator is explicitly counting the 
#number of occurrences. Which is why we only pass the x value

# %%
sns.countplot(x='sex',data=tips)

# %% [markdown]
# # boxplot and violinplot

# %%
#are used to shown the distribution of categorical data.
#A box plot (or box-and-whisker plot) shows the distribution
#of quantitative data in a way that facilitates comparisons 
#between variables or across levels of a categorical variable

# %%
sns.boxplot(x="day", y="total_bill",data=tips,palette='rainbow')

# %%
#Do smokers eat more?
sns.boxplot(x="day",y="total_bill", hue="smoker",data=tips, palette="coolwarm")

# %% [markdown]
# # Regression Plots
# #optional
# #Advanced Section

# %% [markdown]
# # lmplot()

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex') #wrt gender

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex')
#col=Sex -> uts the 2 genders in 2 columns

# %%
#All codes are available at https://github.com/MyDataCafe/
#All Class Videos are at https://www.youtube.com/mydatacafe
#We are on Facebook https://www.facebook.com/mydatacafe/
#We are on LinkedIn https://www.linkedin.com/company/mydatacafe/

# %%
sns.lmplot(x="total_bill", y="tip", row="sex", col="time",data=tips)
#gender in rows and Time in clumns

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
tips[tips['tip']>5].shape
# Out:
# (18, 7)

# %%
(tips[tips['smoker']=="Yes"]['total_bill']).mean()
# Out:
# 20.756344086021507

# %%
tips[(tips['sex']=="Female")&(tips['smoker']=="Yes")]['tip'].max()
# Out:
# 6.5

# %%
#All codes are available at https://github.com/MyDataCafe/
#All Class Videos are at https://www.youtube.com/mydatacafe
#We are on Facebook https://www.facebook.com/mydatacafe/
#We are on LinkedIn https://www.linkedin.com/company/mydatacafe/
